# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
# %cd ../..
# Out:
# /scratch/km817/iREC

# %%
import pickle as pkl
import matplotlib.pyplot as plt
import torch
import torch.distributions as D
import hamiltorch
import torch.nn as nn
import torch.nn.functional as F

# %%
def make_empirical_predictive(weights, x_input, y_output):
    pred_list, _ = hamiltorch.predict_model(net, x = x_input.flatten().to(device),
                                                  y = y_output.flatten().to(device), samples=weights,
                                                  model_loss='regression', tau_out=tau_out,
                                                  tau_list=tau_list)
    
    # need to make gmm at each sample
    return pred_list

def make_empirical_gmm(preds):
    mix = D.Categorical(torch.ones(preds.shape[0]))
    comp = D.Normal(loc=preds.squeeze().permute(1, 0), scale=beta ** -0.5)
    gmm = D.MixtureSameFamily(mix, comp)
    return gmm

def compute_gmm_lp(weights, x, y):
    preds = make_empirical_predictive(weights, x, y)
    
    gmm = make_empirical_gmm(preds)
    
    return gmm.log_prob(y.squeeze()).sum()

def compute_gaussian_likelihood(weights, x, y):
    preds = make_empirical_predictive(weights, x, y)
    
    # make normal using preds and signal noise
    m = preds.mean(0).to('cpu')
    s_al = (preds.var(0).to('cpu') + beta ** -1) ** 0.5
    
    return D.Normal(loc=m, scale=s_al).log_prob(y).sum()

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
plt.rcParams.update({'font.weight': 'normal'})
plt.rcParams.update({'font.size': 16})
plt.rcParams.update({'lines.linewidth' : 2})

# %%
from models.BNNs.DeterministicNN import Deterministic_NN

# %%
def plot_preds(weights, ax=None, title='',
               plt_train_kwargs={'alpha' : 1, 'marker' :'*', 'color':'k', 'rasterized' : True},
               plt_test_kwargs={'alpha' : 0.5, 'marker' :'+', 'color':'k', 'rasterized' : True},
               plt_mean_kwargs={'color':'b', 'rasterized' : True},
               plt_true_kwargs={'color':'r', 'rasterized' : True},
               epistemic_kwargs={'alpha' : 0.5, 'rasterized' : True},
               aleatoric_kwargs={'alpha' : 0.2, 'rasterized' : True},
               fs=16,
               ):
    preds = make_empirical_predictive(weights, xs, ys)
    
    test_ll = compute_gmm_lp(weights, x_test, y_test)
    train_ll = compute_gmm_lp(weights, x_data, y_data)
    if ax is None:
        ax = plt.gca()
    gmm = make_empirical_gmm(preds)
    m = gmm.mean
    s = (gmm.variance - beta ** -1) ** 0.5
    s_al = gmm.stddev
#     m = preds.mean(0).to('cpu')
#     s = preds.std(0).to('cpu')
#     s_al = (preds.var(0).to('cpu') + tau_out ** -1) ** 0.5

    # Get upper and lower confidence bounds
    lower, upper = (m - s*2).flatten(), (m + s*2).flatten()
    # + aleotoric
    lower_al, upper_al = (m - s_al*2).flatten(), (m + s_al*2).flatten()

    # Plot training data as black stars
    ax.scatter(x_data.numpy(), y_data.numpy(), **plt_train_kwargs, label='Train Data')
#     # Plot testing data as black crosses
#     ax.scatter(x_test.numpy(), y_test.numpy(), **plt_test_kwargs, label='Test Data')
    # Plot predictive means as blue line
    ax.plot(xs.numpy(), m.numpy(), **plt_mean_kwargs, label='Mean')
    ax.plot(xs.numpy(), ys.numpy(), **plt_true_kwargs, label='Ground Truth')
    # Shade between the lower and upper confidence bounds
    ax.fill_between(xs.flatten().numpy(), lower.numpy(), upper.numpy(), **epistemic_kwargs, label='Epistemic')
    ax.fill_between(xs.flatten().numpy(), lower_al.numpy(), upper_al.numpy(), **aleatoric_kwargs, label = 'Aleatoric')
    #ax.legend(['Observed Data', 'Mean', 'Ground Truth', 'Epistemic', 'Aleatoric'], fontsize = fs)
    ax.tick_params(axis='both', which='major', labelsize=14)
    ax.tick_params(axis='both', which='minor', labelsize=14)
    ax.set_title(title, fontsize=fs)
    ax.set_xlim(-10., 10.)
#     bbox = {'facecolor': 'white', 'alpha': 0.6, 'pad': 0.5, 'boxstyle': 'round', 'edgecolor':'black'}
#     ax.text(-5, 1.2, f'Test LL: {test_ll:.2f}', bbox=bbox, fontsize=fs, horizontalalignment='center')
#     ax.text(-5, 0.05, f'Train LL: {train_ll:.2f}', bbox=bbox, fontsize=fs, horizontalalignment='center')
    ax.grid()
    return(ax)

# %%
# create toy dataset
torch.set_default_tensor_type(torch.DoubleTensor)
torch.manual_seed(20)
x = torch.cat([torch.Tensor(75).uniform_(-5, -2).sort()[0].reshape(-1, 1),
               torch.Tensor(50).uniform_(2, 5).sort()[0].reshape(-1, 1)])
i = 30
x_data = torch.cat([x[0:i - 15], x[i + 14:]])

# generate some data
alpha, beta, num_nodes = 1., 100., 2

# generate some data
data_generator_model = Deterministic_NN(alpha=alpha, beta=beta, num_nodes=num_nodes)
sampled_weights = data_generator_model.sample_weights_from_prior()
data_generator_model.make_weights_from_sample(sampled_weights)
y_data = data_generator_model(x_data).detach() + (
            1 / data_generator_model.likelihood_beta ** 0.5) * torch.randn_like(
    data_generator_model(x_data).detach())

x_test = torch.Tensor(200).uniform_(-10., 10.).sort()[0]
y_test = data_generator_model(x_test).detach() + (
            1 / data_generator_model.likelihood_beta ** 0.5) * torch.randn_like(
    data_generator_model(x_test).detach()).sort()[0]

xs = torch.linspace(-10, 10, 100)
ys = data_generator_model(xs).detach()

# %%
f, ax = plt.subplots(figsize=(8,6))
ax.plot(x_data,y_data, 'k*')
ax.plot(x_test,y_test, 'k+', alpha=0.25)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.tick_params(axis='both', which='minor', labelsize=14)
#plt.gca().set_aspect('equal')
ax.set_xlabel(r'$x$')
ax.set_ylabel(r'$y$')
ax.plot(xs, ys, 'r')
ax.legend(['Training-data', 'Test-data', 'Ground Truth'], fontsize = 16)
ax.grid()
#f.savefig("Figures/Thesis/BNN_Problem.pdf", bbox_inches='tight')

# %%
plt.figure(figsize=(12,5))
plt.plot(x_data,y_data, 'k*')
plt.plot(xs, ys, 'r')
plt.tick_params(axis='both', which='major', labelsize=14)
plt.tick_params(axis='both', which='minor', labelsize=14)
plt.legend(['Observed Data', 'Ground Truth'], fontsize = 16)
plt.grid()
plt.show()

# %%
device = torch.device('cpu')
class Net(nn.Module):
    def __init__(self, num_nodes: int = 10):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(1, num_nodes)
        self.fc2 = nn.Linear(num_nodes, num_nodes)
        self.fc3 = nn.Linear(num_nodes, 1)

    def forward(self, x):
        x = torch.tanh(self.fc1(x.view(-1, 1)))
        x = torch.tanh(self.fc2(x))
        x = self.fc3(x)
        return x


net = Net(num_nodes=num_nodes)

# %%
# params for plotting 
model_loss = 'regression'
tau = alpha # Prior Precision
tau_out = beta # Output Precision
r = 0 # Random seed


tau_list = []
for w in net.parameters():
    tau_list.append(tau) # set the prior precision to be the same for each set of weights
tau_list = torch.tensor(tau_list).to(device)

# %% [markdown]
# # Epsilon = 0.2

# %%
# load data
epsilon = 0.2
emp_kde_betas = [1., 2, 10., 25.]
var_betas = [0.01, 0.05, 1., 2.]
emp_weights = []
emp_kls = []
for b in emp_kde_betas:
    emp_weights.append(pkl.load(open(f'PickledStuff/BNN_BETA_RESULTS/EMP/emp_beta_{b}_eps_{epsilon:.1f}.pkl', 'rb')))
    emp_kls.append(pkl.load(open(f'PickledStuff/BNN_BETA_RESULTS/EMP/hmc_kl_beta_{b}.pkl', 'rb')))
emp_kls = [t.detach() for t in emp_kls]
kde_weights = []
for b in emp_kde_betas:
    kde_weights.append(pkl.load(open(f'PickledStuff/BNN_BETA_RESULTS/KDE/kde_beta_{b}_eps_{epsilon:.1f}.pkl', 'rb')))

var_weights = []
var_kls = []
for b in var_betas:
    var_weights.append(pkl.load(open(f'PickledStuff/BNN_BETA_RESULTS/VAR/var_beta_{b}_eps_{epsilon:.1f}_new.pkl', 'rb')))
    var_kls.append(pkl.load(open(f'PickledStuff/BNN_BETA_RESULTS/VAR/var_kl_beta_{b}.pkl', 'rb')))
var_kls = [t.detach() for t in var_kls]

# %%
emp_train_lls = torch.zeros([0])
emp_test_lls = torch.zeros([0])
for w in emp_weights:
    emp_train_lls = torch.cat([emp_train_lls, compute_gmm_lp(w, x_data, y_data)[None]])
    emp_test_lls = torch.cat([emp_test_lls, compute_gmm_lp(w, x_test, y_test)[None]])

kde_train_lls = torch.zeros([0])
kde_test_lls = torch.zeros([0])
for w in kde_weights:
    kde_train_lls = torch.cat([kde_train_lls, compute_gmm_lp(w, x_data, y_data)[None]])
    kde_test_lls = torch.cat([kde_test_lls, compute_gmm_lp(w, x_test, y_test)[None]])

var_train_lls = torch.zeros([0])
var_test_lls = torch.zeros([0])
for w in var_weights:
    var_train_lls = torch.cat([var_train_lls, compute_gmm_lp(w, x_data, y_data)[None]])
    var_test_lls = torch.cat([var_test_lls, compute_gmm_lp(w, x_test, y_test)[None]])

# %%
# load data
epsilon = 0.2
emp_kde_betas = [1., 2, 10., 25.]
var_betas = [0.01, 0.05, 1., 2.]
emp_exact_weights = []
for b in emp_kde_betas:
    emp_exact_weights.append(pkl.load(open(f'PickledStuff/BNN_BETA_RESULTS/EMP/HMC_beta_{b}.pkl', 'rb')))
emp_kls = [t.detach() for t in emp_kls]
kde_exact_weights = []
for b in emp_kde_betas:
    kde_exact_weights.append(pkl.load(open(f'PickledStuff/BNN_BETA_RESULTS/KDE/kde_exact_beta_{b}.pkl', 'rb')))

var_exact_weights = []
for b in var_betas:
    var_exact_weights.append(pkl.load(open(f'PickledStuff/BNN_BETA_RESULTS/VAR/var_exact_beta_{b}.pkl', 'rb')))

# %%
emp_exact_train_lls = torch.zeros([0])
emp_exact_test_lls = torch.zeros([0])
for w in emp_exact_weights:
    emp_exact_train_lls = torch.cat([emp_exact_train_lls, compute_gmm_lp(w, x_data, y_data)[None]])
    emp_exact_test_lls = torch.cat([emp_exact_test_lls, compute_gmm_lp(w, x_test, y_test)[None]])

kde_exact_train_lls = torch.zeros([0])
kde_exact_test_lls = torch.zeros([0])
for w in kde_exact_weights:
    kde_exact_train_lls = torch.cat([kde_exact_train_lls, compute_gmm_lp(w, x_data, y_data)[None]])
    kde_exact_test_lls = torch.cat([kde_exact_test_lls, compute_gmm_lp(w, x_test, y_test)[None]])

var_exact_train_lls = torch.zeros([0])
var_exact_test_lls = torch.zeros([0])
for w in var_exact_weights:
    var_exact_train_lls = torch.cat([var_exact_train_lls, compute_gmm_lp(w, x_data, y_data)[None]])
    var_exact_test_lls = torch.cat([var_exact_test_lls, compute_gmm_lp(w, x_test, y_test)[None]])

# %%
f, ax = plt.subplots(1, 2, figsize=(15, 8), sharex=True, sharey=False)
ax[0].plot(emp_kls, emp_test_lls, '-o')
ax[0].plot(emp_kls, kde_test_lls, '-o')
ax[0].plot(var_kls, var_test_lls, '-o')
ax[0].grid()
ax[0].set_xlabel(r'$\operatorname{KL}\left(q(\mathbf{w}|\mathcal{D}) \| p(\mathbf{w})\right)$', fontsize=16)
ax[1].plot(emp_kls, emp_train_lls, '-o')
ax[1].plot(emp_kls, kde_train_lls, '-o')
ax[1].plot(var_kls, var_train_lls, '-o')
ax[1].grid()
ax[1].set_xlabel(r'$\operatorname{KL}\left(q(\mathbf{w}|\mathcal{D}) \| p(\mathbf{w})\right)$', fontsize=16)
ax[0].set_title('Log-likelihood test-set', fontsize=16)
ax[1].set_title('Log-likelihood training-set', fontsize=16)
ax[0].tick_params(axis='both', which='major', labelsize=14)
ax[0].tick_params(axis='both', which='minor', labelsize=14)
ax[1].tick_params(axis='both', which='minor', labelsize=14)
ax[1].tick_params(axis='both', which='major', labelsize=14)
f.legend(['Compressed EMP', 'Compressed KDE', 'Compressed VAR'], loc = (0.9, 0.5), ncol=1, fontsize=16)
f.tight_layout()

# %%
def compute_expected_coding_efficiency(kl, epsilon=0.2):
    K = (1 + epsilon) * kl
    return K + torch.log(K + 1) + 1

# %%
emp_expected_coding_efficiency = [compute_expected_coding_efficiency(kl) for kl in emp_kls]

var_expected_coding_efficiency = [compute_expected_coding_efficiency(kl) for kl in var_kls]

# %%
f, ax = plt.subplots(1, 2, figsize=(15, 8), sharex=True, sharey=False)
ax[0].plot(emp_expected_coding_efficiency, emp_test_lls, '-o')
ax[0].plot(emp_expected_coding_efficiency, kde_test_lls, '-o')
ax[0].plot(var_expected_coding_efficiency, var_test_lls, '-o')
ax[0].grid()
ax[0].set_xlabel('Nats per sample', fontsize=16)
ax[1].plot(emp_expected_coding_efficiency, emp_train_lls, '-o')
ax[1].plot(emp_expected_coding_efficiency, kde_train_lls, '-o')
ax[1].plot(var_expected_coding_efficiency, var_train_lls, '-o')
ax[1].grid()
ax[1].set_xlabel('Nats per sample', fontsize=16)
ax[0].set_title('Log-likelihood test-set', fontsize=16)
ax[1].set_title('Log-likelihood training-set', fontsize=16)
ax[0].tick_params(axis='both', which='major', labelsize=14)
ax[0].tick_params(axis='both', which='minor', labelsize=14)
ax[1].tick_params(axis='both', which='minor', labelsize=14)
ax[1].tick_params(axis='both', which='major', labelsize=14)
f.legend(['MOD-Scheme', 'KDE-Scheme', 'FG-Scheme'], loc = (0.8, 0.3), ncol=1, fontsize=16)
f.tight_layout()
#f.savefig("Figures/Thesis/BNN_BETA_RESULTS.pdf", bbox_inches='tight')

# %%
f, ax = plt.subplots(1, 2, figsize=(15, 8), sharex=True, sharey=False)
ax[0].plot(emp_kls, emp_test_lls, '-o')
ax[0].plot(emp_kls, kde_test_lls, '-o')
ax[0].plot(var_kls, var_test_lls, '-o')
ax[0].set_prop_cycle(None)
ax[0].plot(emp_kls, emp_exact_test_lls, '--o')
ax[0].plot(emp_kls, kde_exact_test_lls, '--o')
ax[0].plot(var_kls, var_exact_test_lls, '--o')
ax[0].grid()
ax[0].set_xlabel(r'$\operatorname{KL}\left(q(\mathbf{w}|\mathcal{D}) \| p(\mathbf{w})\right)$', fontsize=16)
ax[1].plot(emp_kls, emp_train_lls, '-o')
ax[1].plot(emp_kls, kde_train_lls, '-o')
ax[1].plot(var_kls, var_train_lls, '-o')
ax[1].set_prop_cycle(None)
ax[1].plot(emp_kls, emp_exact_train_lls, '--o')
ax[1].plot(emp_kls, kde_exact_train_lls, '--o')
ax[1].plot(var_kls, var_exact_train_lls, '--o')
ax[1].grid()
ax[1].set_xlabel(r'$\operatorname{KL}\left(q(\mathbf{w}|\mathcal{D}) \| p(\mathbf{w})\right)$', fontsize=16)
ax[0].set_title('Log-likelihood test-set', fontsize=16)
ax[1].set_title('Log-likelihood training-set', fontsize=16)
ax[0].tick_params(axis='both', which='major', labelsize=14)
ax[0].tick_params(axis='both', which='minor', labelsize=14)
ax[1].tick_params(axis='both', which='minor', labelsize=14)
ax[1].tick_params(axis='both', which='major', labelsize=14)
f.legend(['MOD-Scheme', 'KDE-Scheme', 'FG-Scheme', 'Exact HMC', 'Exact KDE', 'Exact FG'], loc = (0.8, 0.2), ncol=1, fontsize=16)
f.tight_layout()
f.savefig("Figures/Thesis/BNN_RESULTS_EXACT.pdf", bbox_inches='tight')

# %%
emp_exact_train_lls_gauss = torch.zeros([0])
emp_exact_test_lls_gauss = torch.zeros([0])
for w in emp_exact_weights:
    emp_exact_train_lls_gauss = torch.cat([emp_exact_train_lls_gauss, compute_gaussian_likelihood(w, x_data, y_data)[None]])
    emp_exact_test_lls_gauss = torch.cat([emp_exact_test_lls_gauss, compute_gaussian_likelihood(w, x_test, y_test)[None]])

kde_exact_train_lls_gauss = torch.zeros([0])
kde_exact_test_lls_gauss = torch.zeros([0])
for w in kde_exact_weights:
    kde_exact_train_lls_gauss = torch.cat([kde_exact_train_lls_gauss, compute_gaussian_likelihood(w, x_data, y_data)[None]])
    kde_exact_test_lls_gauss = torch.cat([kde_exact_test_lls_gauss, compute_gaussian_likelihood(w, x_test, y_test)[None]])

var_exact_train_lls_gauss = torch.zeros([0])
var_exact_test_lls_gauss = torch.zeros([0])
for w in var_exact_weights:
    var_exact_train_lls_gauss = torch.cat([var_exact_train_lls_gauss, compute_gaussian_likelihood(w, x_data, y_data)[None]])
    var_exact_test_lls_gauss = torch.cat([var_exact_test_lls_gauss, compute_gaussian_likelihood(w, x_test, y_test)[None]])

# %%
emp_train_lls_gauss = torch.zeros([0])
emp_test_lls_gauss = torch.zeros([0])
for w in emp_weights:
    emp_train_lls_gauss = torch.cat([emp_train_lls_gauss, compute_gaussian_likelihood(w, x_data, y_data)[None]])
    emp_test_lls_gauss = torch.cat([emp_test_lls_gauss, compute_gaussian_likelihood(w, x_test, y_test)[None]])

kde_train_lls_gauss = torch.zeros([0])
kde_test_lls_gauss = torch.zeros([0])
for w in kde_weights:
    kde_train_lls_gauss = torch.cat([kde_train_lls_gauss, compute_gaussian_likelihood(w, x_data, y_data)[None]])
    kde_test_lls_gauss = torch.cat([kde_test_lls_gauss, compute_gaussian_likelihood(w, x_test, y_test)[None]])

var_train_lls_gauss = torch.zeros([0])
var_test_lls_gauss = torch.zeros([0])
for w in var_weights:
    var_train_lls_gauss = torch.cat([var_train_lls_gauss, compute_gaussian_likelihood(w, x_data, y_data)[None]])
    var_test_lls_gauss = torch.cat([var_test_lls_gauss, compute_gaussian_likelihood(w, x_test, y_test)[None]])

# %%
f, ax = plt.subplots(1, 2, figsize=(15, 8), sharex=True, sharey=False)
ax[0].plot(emp_kls, emp_test_lls_gauss, '-o')
ax[0].plot(emp_kls, kde_test_lls_gauss, '-o')
ax[0].plot(var_kls, var_test_lls_gauss, '-o')
ax[0].plot(emp_kls, emp_exact_test_lls_gauss, '-o')
ax[0].plot(emp_kls, kde_exact_test_lls_gauss, '-o')
ax[0].plot(var_kls, var_exact_test_lls_gauss, '-o')
ax[0].grid()
ax[0].set_xlabel(r'$\operatorname{KL}\left(q(\mathbf{w}|\mathcal{D}) \| p(\mathbf{w})\right)$', fontsize=16)
ax[1].plot(emp_kls, emp_train_lls_gauss, '-o')
ax[1].plot(emp_kls, kde_train_lls_gauss, '-o')
ax[1].plot(var_kls, var_train_lls_gauss, '-o')
ax[1].plot(emp_kls, emp_exact_train_lls_gauss, '-o')
ax[1].plot(emp_kls, kde_exact_train_lls_gauss, '-o')
ax[1].plot(var_kls, var_exact_train_lls_gauss, '-o')
ax[1].grid()
ax[1].set_xlabel(r'$\operatorname{KL}\left(q(\mathbf{w}|\mathcal{D}) \| p(\mathbf{w})\right)$', fontsize=16)
ax[0].set_title('Log-likelihood test-set', fontsize=16)
ax[1].set_title('Log-likelihood training-set', fontsize=16)
ax[0].tick_params(axis='both', which='major', labelsize=14)
ax[0].tick_params(axis='both', which='minor', labelsize=14)
ax[1].tick_params(axis='both', which='minor', labelsize=14)
ax[1].tick_params(axis='both', which='major', labelsize=14)
f.legend(['Compressed EMP', 'Compressed KDE', 'Compressed VAR', 'HMC', 'KDE', 'VAR'], loc = (0.8, 0.2), ncol=1, fontsize=16)
f.suptitle('Gaussian Predictive', fontsize=24)
f.tight_layout()

# %%
f, ax = plt.subplots(1, 2, figsize=(15, 8), sharex=True, sharey=False)
ax[0].plot(emp_expected_coding_efficiency, emp_test_lls_gauss, '-o')
ax[0].plot(emp_expected_coding_efficiency, kde_test_lls_gauss, '-o')
ax[0].plot(var_expected_coding_efficiency, var_test_lls_gauss, '-o')
ax[0].grid()
ax[0].set_xlabel('Nats per sample', fontsize=16)
ax[1].plot(emp_expected_coding_efficiency, emp_train_lls_gauss, '-o')
ax[1].plot(emp_expected_coding_efficiency, kde_train_lls_gauss, '-o')
ax[1].plot(var_expected_coding_efficiency, var_train_lls_gauss, '-o')
ax[1].grid()
ax[1].set_xlabel('Nats per sample', fontsize=16)
ax[0].set_title('Log-likelihood test-set', fontsize=16)
ax[1].set_title('Log-likelihood training-set', fontsize=16)
ax[0].tick_params(axis='both', which='major', labelsize=14)
ax[0].tick_params(axis='both', which='minor', labelsize=14)
ax[1].tick_params(axis='both', which='minor', labelsize=14)
ax[1].tick_params(axis='both', which='major', labelsize=14)
f.legend(['EMP', 'KDE', 'VAR'], loc = (0.9, 0.5), ncol=1, fontsize=16)
f.tight_layout()

# %% [markdown]
# # Plotting Predictives

# %%
plt.figure(figsize=(12,5))
for p in make_empirical_predictive(emp_exact_weights[-1], xs, ys):
    plt.plot(xs, p, 'blue', alpha=0.1)
plt.plot(x_data,y_data, 'k*')
plt.plot(xs, ys, 'r')
plt.tick_params(axis='both', which='major', labelsize=14)
plt.tick_params(axis='both', which='minor', labelsize=14)
plt.legend(['Observed Data', 'Ground Truth'], fontsize = 16)
plt.grid()

# %%
make_empirical_gmm(make_empirical_predictive(emp_exact_weights[1], xs, ys)).stddev - beta ** -0.5

# %%
fs=16
f, (ax1, ax2) = plt.subplots(2,3, figsize=(15,7.5), sharex=True, sharey=True)
ax1[0] = plot_preds(emp_exact_weights[0], ax=ax1[0])
ax1[0].set_title('HMC', fontsize=fs)
ax1[1] = plot_preds(kde_exact_weights[0], ax=ax1[1])
ax1[2] = plot_preds(var_exact_weights[-1], ax=ax1[2])
ax1[1].set_title('KDE', fontsize=fs)
ax1[2].set_title('VAR', fontsize=fs)
ax2[0] = plot_preds(emp_weights[0], ax=ax2[0])
ax2[1] = plot_preds(kde_weights[0], ax=ax2[1])
ax2[2] = plot_preds(var_weights[-1], ax=ax2[2])
ax2[2].legend(fontsize = fs)
f.tight_layout()

# %%
# load data
true_hmc_weights = pkl.load(open('PickledStuff/BNN_STUFF/HMC_TRUE_WEIGHTS.pkl', 'rb'))
compressed_weights_kde_exact = pkl.load(open('PickledStuff/BNN_STUFF/kde_exact_beta_1_1000.pkl', 'rb'))
compressed_weights_kde_high_eps = pkl.load(open('PickledStuff/BNN_STUFF/kde_beta_1_eps_0.2_1000.pkl', 'rb'))
compressed_weights_emp_high_eps = pkl.load(open('PickledStuff/BNN_STUFF/emp_0.2_1000.pkl', 'rb'))
compressed_weights_var_exact = pkl.load(open('PickledStuff/BNN_STUFF/var_exact_beta_1.pkl', 'rb'))
compressed_weights_var_low_eps = pkl.load(open('PickledStuff/BNN_STUFF/var_beta_1_eps_0.pkl', 'rb'))
compressed_weights_var_med_eps = pkl.load(open('PickledStuff/BNN_STUFF/var_beta_1_eps_0.1.pkl', 'rb'))
compressed_weights_var_high_eps = pkl.load(open('PickledStuff/BNN_STUFF/var_beta_1_eps_0.2.pkl', 'rb'))

# %%
fs=16
f, (ax1, ax2) = plt.subplots(2,3, figsize=(18,10), sharex=True, sharey=True)
ax1[0] = plot_preds(true_hmc_weights, ax=ax1[0])
ax1[0].set_title('HMC', fontsize=fs)
ax2[0].set_title('MOD-Scheme', fontsize=fs)
ax1[1] = plot_preds(compressed_weights_kde_exact, ax=ax1[1])
ax1[2] = plot_preds(compressed_weights_var_exact, ax=ax1[2])
ax1[1].set_title('KDE', fontsize=fs)
ax2[1].set_title('KDE-Scheme', fontsize=fs)
ax1[2].set_title('FG', fontsize=fs)
ax2[2].set_title('FG-Scheme', fontsize=fs)
ax2[0] = plot_preds(emp_weights[0], ax=ax2[0])
ax2[1] = plot_preds(kde_weights[0], ax=ax2[1])
ax2[2] = plot_preds(var_weights[-2], ax=ax2[2])
ax2[2].legend(fontsize = fs)
ax2[0].set_xlabel(r'$x$')
ax2[0].set_ylabel(r'$y$')
ax2[1].set_xlabel(r'$x$')
ax2[2].set_xlabel(r'$x$')
ax1[0].set_ylabel(r'$y$')


f.tight_layout()
#f.savefig("Figures/Thesis/bnn_beta_1_plots.pdf", bbox_inches='tight')

# %%
fig = plt.figure(constrained_layout=True, figsize=(18,10))
row_titles = ['Uncompressed Samples', 'Compressed Samples']
col_titles = [['HMC', 'MOD-Scheme'], ['KDE', 'KDE-Scheme'], ['Factored-Gaussian', 'FG-Scheme']]
preds = [[true_hmc_weights, compressed_weights_kde_exact, compressed_weights_var_exact], 
         [emp_weights[0], kde_weights[0], var_weights[-2]]]
# create 3x1 subfigs
subfigs = fig.subfigures(nrows=2, ncols=1)
for row, subfig in enumerate(subfigs):
    #subfig.suptitle(row_titles[row])
    # create 1x3 subplots per subfig
    axs = subfig.subplots(nrows=1, ncols=3, sharex=True, sharey=True)
    for col, ax in enumerate(axs):
        if col == 0:
            ax.set_ylabel(r'$y$')
        ax.set_xlabel(r'$x$')
        ax = plot_preds(preds[row][col], ax=ax)
        ax.set_title(col_titles[col][row], fontsize=18)
        ax.tick_params(axis='both', which='major', labelsize=17)
        ax.tick_params(axis='both', which='minor', labelsize=17)
        if col==2 and row==0:
            ax.legend(fontsize=17, loc='upper right')

fig.savefig("Figures/Thesis/bnn_beta_1_plots.pdf", bbox_inches='tight')
